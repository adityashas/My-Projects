# %%
import face_recognition
import cv2
import os
import sys
import os.path
import csv

def CreateCsv(csvLine):  
    
    BASE_PATH=csvLine
    SEPARATOR=","

    label = 0
    with open("face_dataset.csv", "w") as file:
     writer = csv.writer(file)
     for dirname, dirnames, filenames in os.walk(BASE_PATH):
            for subdirname in dirnames:
                subject_path = os.path.join(dirname, subdirname)
                for filename in os.listdir(subject_path):
                    abs_path = "%s/%s" % (subject_path, filename)
                    csv_line = "%s%s%d" % (abs_path, SEPARATOR, label)
                    print (csv_line)
                    writer.writerows([csv_line.split(',')])
                label = label + 1
                




import face_recognition
import cv2
import os

facedetect = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

#cap = cv2.VideoCapture(0)
#fourcc = cv2.VideoWriter_fourcc(*'XVID')
#fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
#out = cv2.VideoWriter('test1.avi',fourcc, 20.0, (int(video_capture.get(3)),int(video_capture.get(4))))
current_path = os.getcwd()
# Load a sample picture and learn how to recognize it.
seshu_image = face_recognition.load_image_file("seshu.jpg")
seshu_face_encoding = face_recognition.face_encodings(seshu_image)[0]

seshu2_image = face_recognition.load_image_file("seshu2.jpg")
seshu2_face_encoding = face_recognition.face_encodings(seshu2_image)[0]

seshu3_image = face_recognition.load_image_file("seshu3.jpg")
seshu3_face_encoding = face_recognition.face_encodings(seshu3_image)[0]


seshu4_image = face_recognition.load_image_file("seshu/1.jpg")
seshu4_face_encoding = face_recognition.face_encodings(seshu4_image)[0]

seshu5_image = face_recognition.load_image_file("seshu/2.jpg")
seshu5_face_encoding = face_recognition.face_encodings(seshu5_image)[0]

#seshu6_image = face_recognition.load_image_file("seshu/3.jpg")
#seshu6_face_encoding = face_recognition.face_encodings(seshu5_image)[0]

seshu7_image = face_recognition.load_image_file("seshu/4.jpg")
seshu7_face_encoding = face_recognition.face_encodings(seshu7_image)[0]

seshu8_image = face_recognition.load_image_file("seshu/5.jpg")
seshu8_face_encoding = face_recognition.face_encodings(seshu8_image)[0]

seshu9_image = face_recognition.load_image_file("seshu/5.jpg")
seshu9_face_encoding = face_recognition.face_encodings(seshu9_image)[0]

seshu10_image = face_recognition.load_image_file("seshu/7.jpg")
seshu10_face_encoding = face_recognition.face_encodings(seshu10_image)[0]


kirtika_image = face_recognition.load_image_file("kritika.jpg")
kirtika_face_encoding = face_recognition.face_encodings(kirtika_image)[0]

kirtika2_image = face_recognition.load_image_file("kritika3.jpg")
kirtika2_face_encoding = face_recognition.face_encodings(kirtika2_image)[0]

kirtika3_image = face_recognition.load_image_file("kritika/1.jpg")
kirtika3_face_encoding = face_recognition.face_encodings(kirtika3_image)[0]

kirtika4_image = face_recognition.load_image_file("kritika/2.jpg")
kirtika4_face_encoding = face_recognition.face_encodings(kirtika4_image)[0]

kirtika5_image = face_recognition.load_image_file("kritika/3.jpg")
kirtika5_face_encoding = face_recognition.face_encodings(kirtika5_image)[0]

kirtika6_image = face_recognition.load_image_file("kritika/4.jpg")
kirtika6_face_encoding = face_recognition.face_encodings(kirtika6_image)[0]

kirtika7_image = face_recognition.load_image_file("kritika/5.jpg")
kirtika7_face_encoding = face_recognition.face_encodings(kirtika7_image)[0]

kirtika8_image = face_recognition.load_image_file("kritika/6.jpg")
kirtika8_face_encoding = face_recognition.face_encodings(kirtika8_image)[0]



ravi_image = face_recognition.load_image_file("ravi.jpg")
ravi_face_encoding = face_recognition.face_encodings(ravi_image)[0]

madhu_image = face_recognition.load_image_file("madhu.jpg")
madhu_face_encoding = face_recognition.face_encodings(madhu_image)[0]

madhu2_image = face_recognition.load_image_file("madhu2.jpg")
madhu2_face_encoding = face_recognition.face_encodings(madhu2_image)[0]

madhu3_image = face_recognition.load_image_file("madhu2.jpg")
madhu3_face_encoding = face_recognition.face_encodings(madhu3_image)[0]


upasana_image = face_recognition.load_image_file("upasana.jpg")
upasana_face_encoding = face_recognition.face_encodings(upasana_image)[0]

upasana2_image = face_recognition.load_image_file("upasana2.jpg")
upasana2_face_encoding = face_recognition.face_encodings(upasana2_image)[0]

upasana3_image = face_recognition.load_image_file("upasana2.jpg")
upasana3_face_encoding = face_recognition.face_encodings(upasana3_image)[0]


arun_image = face_recognition.load_image_file("arun.jpg")
arun_face_encoding = face_recognition.face_encodings(arun_image)[0]

arun2_image = face_recognition.load_image_file("arun2.jpg")
arun2_face_encoding = face_recognition.face_encodings(arun2_image)[0]

arun3_image = face_recognition.load_image_file("arun2.jpg")
arun3_face_encoding = face_recognition.face_encodings(arun3_image)[0]



arjun_image = face_recognition.load_image_file("aaa.jpg")
arjun_face_encoding = face_recognition.face_encodings(arjun_image)[0]

arjun2_image = face_recognition.load_image_file("arjun2.jpg")
arjun2_face_encoding = face_recognition.face_encodings(arjun2_image)[0]

arjun3_image = face_recognition.load_image_file("arjun3.jpg")
arjun3_face_encoding = face_recognition.face_encodings(arjun3_image)[0]

arjun4_image = face_recognition.load_image_file("arjun4.jpg")
arjun4_face_encoding = face_recognition.face_encodings(arjun4_image)[0]

arjun5_image = face_recognition.load_image_file("arjun5.jpg")
arjun5_face_encoding = face_recognition.face_encodings(arjun5_image)[0]

arjun6_image = face_recognition.load_image_file("arjun6.jpg")
arjun6_face_encoding = face_recognition.face_encodings(arjun6_image)[0]



mrityunjay_image = face_recognition.load_image_file("mrityunjay.jpg")
mrityunjay_face_encoding = face_recognition.face_encodings(mrityunjay_image)[0]


rajan_image = face_recognition.load_image_file("rajan.jpg")
rajan_face_encoding = face_recognition.face_encodings(rajan_image)[0]

mohinder_image = face_recognition.load_image_file("mohinder.jpg")
mohinder_face_encoding = face_recognition.face_encodings(mohinder_image)[0]


known_faces = [seshu_face_encoding,seshu2_face_encoding,seshu3_face_encoding,kirtika_face_encoding,kirtika2_face_encoding,kirtika3_face_encoding,
               ravi_face_encoding,madhu_face_encoding,madhu2_face_encoding,madhu3_face_encoding,
               upasana_face_encoding,upasana2_face_encoding,upasana3_face_encoding,
               arun_face_encoding,arun2_face_encoding,arun3_face_encoding,
               arjun_face_encoding,arjun2_face_encoding,arjun3_face_encoding,
               mrityunjay_face_encoding,rajan_face_encoding,mohinder_face_encoding,
              seshu4_face_encoding,seshu5_face_encoding,seshu7_face_encoding,seshu8_face_encoding,seshu9_face_encoding,seshu10_face_encoding,
              kirtika4_face_encoding ,kirtika5_face_encoding ,kirtika6_face_encoding,kirtika7_face_encoding ,kirtika8_face_encoding  ]    
#print(madhu_face_encoding)
# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e312f1299b53> in <module>()
#       1 import face_recognition
# ----> 2 import cv2
#       3 import os
#       4 import sys
#       5 import os.path
#
# ImportError: numpy.core.multiarray failed to import

# %%
import face_recognition

# Load the jpg files into numpy arrays
biden_image = face_recognition.load_image_file("my.jpg")
#obama_image = face_recognition.load_image_file("obama.jpg")
unknown_image = face_recognition.load_image_file("index.jpeg")

# Get the face encodings for each face in each image file
# Since there could be more than one face in each image, it returns a list of encodings.
# But since I know each image only has one face, I only care about the first encoding in each image, so I grab index 0.
biden_face_encoding = face_recognition.face_encodings(biden_image)[0]
#obama_face_encoding = face_recognition.face_encodings(obama_image)[0]
unknown_face_encoding = face_recognition.face_encodings(unknown_image)[0]

known_faces = [
    biden_face_encoding,
    #obama_face_encoding
]

# results is an array of True/False telling if the unknown face matched anyone in the known_faces array
results = face_recognition.compare_faces(known_faces, unknown_face_encoding)

print("Is the unknown face a picture of Biden? {}".format(results[0]))
#print("Is the unknown face a picture of Obama? {}".format(results[1]))
print("Is the unknown face a new person that we've never seen before? {}".format(not True in results))
