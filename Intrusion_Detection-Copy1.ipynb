# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import pandas as pd
import pymysql
import datetime
dbServerName    = "35.154.4.16"

dbUser          = "demo_ai"

dbPassword      = "xvidia@ai"

dbName          = "demo_ai"

#charSet         = "utf8mb4"



cusrorType      = pymysql.cursors.DictCursor

 

connectionObject   = pymysql.connect(host=dbServerName, user=dbUser, password=dbPassword,

                                     db=dbName,cursorclass=cusrorType)
cursorObject        = connectionObject.cursor()

# %%
now=datetime.datetime.now()
date1=str(now.year)+"-"+str(now.month)+"-"+str(now.day)
time1=str(now.hour)+":"+str(now.minute)+":"+str(now.second)
x=str("'"+str(date1)+"'")
y=str("'"+str(time1)+"'")
#z=str("'"+str(n)+"'")
print(x,y)
#cursorObject.execute("INSERT INTO camera(CameraName,CameraRtsp,CameraMp4,LogTime) VALUES ('rtsp123','kkkk','video','"+str(now)+"')")
#connectionObject.commit()
cursorObject.execute("SELECT * from camera")
# Fetch a single row using fetchone() method.
data = cursorObject.fetchall()
print (data)
# Out:
# '2018-1-16' '13:25:4'
# ...

# %%
#import smtplib 
#gmailaddress = 'storemonitor@xvidia.net'
#gmailpassword = 'Media$122001@610'
#mailto = 'aditya_shas@yahoo.com'
#msg = 'Intruder Found. Go through Link-- rtsp://admin:admin@xvidiaoffice.selfip.com:8554/cam/realmonitor?channel=1&subtype=0'
#mailServer = smtplib.SMTP('smtp.gmail.com' , 587)
#mailServer.starttls()
#mailServer.login(gmailaddress , gmailpassword)
import numpy as np
import cv2
import smtplib 
import datetime
CLASSES = ["background", "aeroplane", "bicycle", "bird", "boat",
"bottle", "bus", "car", "cat", "chair", "cow", "diningtable",
"dog", "horse", "motorbike", "person", "pottedplant", "sheep",
"sofa", "train", "tvmonitor"]
COLORS = np.random.uniform(0, 255, size=(len(CLASSES), 3))


net = cv2.dnn.readNetFromCaffe('MobileNetSSD_deploy.prototxt.txt', 'MobileNetSSD_deploy.caffemodel')
print("[INFO] starting video stream...")
vs=cv2.VideoCapture('rtsp://admin:admin@xvidiadev.selfip.com:544/cam/realmonitor?channel=1&subtype=0')
fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
out = cv2.VideoWriter('intrusion_program.avi',fourcc, 20.0, (704,576))

area = (400, 400, 800, 800)

def mail_to():
    print("Sending mail...")
    gmailaddress = 'storemonitor@xvidia.net'
    gmailpassword = 'Media$122001@610'
    mailto = 'aditya_shas@yahoo.com'
    msg = 'Intruder Found. Go through Link-- rtsp://admin:admin@xvidiaoffice.selfip.com:8554/cam/realmonitor?channel=1&subtype=0'
    mailServer = smtplib.SMTP('smtp.gmail.com' , 587)
    mailServer.starttls()
    mailServer.login(gmailaddress , gmailpassword)
    mailServer.sendmail(gmailaddress, mailto , msg)
    print(" \n Sent!")
    mailServer.quit()
    return
    
def strt_rec(cap,count,arg,now):
    print("Start Recording... at  ",now)
    x='intrusion_'+str(count)+'.avi'
    out = cv2.VideoWriter(str(x),fourcc, 5.0, (704,576))
    i=0 
    
    
    while(i<60 or arg==1):
       
       ret,frame=cap.read()
       _,arg,now=intrusion(frame,count)
       out.write(frame)
       i+=1
    print("Recording done to ",x)
    cursorObject.execute("INSERT INTO camera(CameraName,CameraRtsp,CameraMp4,LogTime) VALUES ('Office-Xvidia','rtsp://admin:admin@xvidiaoffice.selfip.com:8554/cam/realmonitor?channel=1&subtype=0','"+str(x)+"','"+str(now)+"')")
    connectionObject.commit()
    return

def intrusion(frame,count):
 arg=0
 now=datetime.datetime.now()
 (h, w) = frame.shape[:2]
 blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)),0.007843, (300, 300), 127.5)
 net.setInput(blob)
 detections = net.forward()
 for i in np.arange(0, detections.shape[2]):
  confidence = detections[0, 0, i, 2]
  if confidence > 0.1:
    idx = int(detections[0, 0, i, 1])
    if idx==15:
        arg=1
        count=count+1
        now=datetime.datetime.now()
 return count,arg,now  
arg=0
count=0
while True:
 ret,frame = vs.read()
 count,arg,now=intrusion(frame,count)
 if arg==1:
    #mail_to()
    strt_rec(vs,count,arg,now)
    arg=0
 #cv2.imshow("Frame", frame)
 out.write(frame)
 key = cv2.waitKey(1) & 0xFF

 if key == ord("q"):
   break
vs.release()
# Out:
# [INFO] starting video stream...
# Start Recording... at   2018-01-16 13:23:53.798253
# Recording done to  intrusion_1.avi

# %%
import smtplib 
gmailaddress = 'storemonitor@xvidia.net'
gmailpassword = 'Media$122001@610'
mailto = 'aditya_shas@yahoo.com'
msg = 'Hai How are you'
mailServer = smtplib.SMTP('smtp.gmail.com' , 587)
mailServer.starttls()
mailServer.login(gmailaddress , gmailpassword)
mailServer.sendmail(gmailaddress, mailto , msg)
print(" \n Sent!")
mailServer.quit()
# Out:
#
#  Sent!
# (221, b'2.0.0 closing connection p93sm1038380edp.14 - gsmtp')

# %%
import numpy as np
import argparse
import cv2
#from imutils.video import VideoStream
#from imutils.video import FPS
import numpy as np
import argparse
#import imutils
import time
import cv2
#from pygame import mixer
#mixer.init() #you must initialize the mixer
#alert=mixer.Sound('beep.wav')
import os

CLASSES = ["background", "aeroplane", "bicycle", "bird", "boat",
"bottle", "bus", "car", "cat", "chair", "cow", "diningtable",
"dog", "horse", "motorbike", "person", "pottedplant", "sheep",
"sofa", "train", "tvmonitor"]
COLORS = np.random.uniform(0, 255, size=(len(CLASSES), 3))


net = cv2.dnn.readNetFromCaffe('MobileNetSSD_deploy.prototxt.txt', 'MobileNetSSD_deploy.caffemodel')

print("[INFO] starting video stream...")
#vs = VideoStream(src=0).start()
#vs=cv2.VideoCapture("/home/seshu/chainer-caption/sample_imgs/Ayyappacommunication791.103000.mp4")
vs=cv2.VideoCapture('rtsp://admin:admin@xvidiaoffice.selfip.com:8554/cam/realmonitor?channel=1&subtype=0')
#vs=cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
out = cv2.VideoWriter('Intrusion.avi',fourcc, 20.0, (704,576))
#print(int(vs.get(3)),int(vs.get(4)))
#fps = FPS().start()


from PIL import Image
#from imutils.video import VideoStream
#from imutils.video import FPS
import numpy as np
import argparse
#import imutils
#import time
import cv2
#import pyttsx
#import create_csv
#engine = pyttsx.init()

bottomLeftCornerOfText = (10,20)
fontScale              = 1
fontColor              = (255,255,255)
lineType               = 2

area = (400, 400, 800, 800)

while True:
 # grab the frame from the threaded video stream and resize it
 # to have a maximum width of 400 pixels

 ret,frame = vs.read()
 framess=frame
 #frame = imutils.resize(frame, width=800)
 raw_frame=frame
 #print(frame.shape)
 #frame=frame[0:380, 0:120]
 # grab the frame dimensions and convert it to a blob
 (h, w) = frame.shape[:2]
 blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)),0.007843, (300, 300), 127.5)
 
 # pass the blob through the network and obtain the detections and
 # predictions
 net.setInput(blob)
 detections = net.forward()
 count=0

 for i in np.arange(0, detections.shape[2]):
  # extract the confidence (i.e., probability) associated with
  # the prediction
  confidence = detections[0, 0, i, 2]
 
  # filter out weak detections by ensuring the `confidence` is
  # greater than the minimum confidence
  if confidence > 0.3:
  # extract the index of the class label from the
  # `detections`, then compute the (x, y)-coordinates of
  # the bounding box for the object
    
    idx = int(detections[0, 0, i, 1])
    if idx==15:
        count=count+1
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        (startX, startY, endX, endY) = box.astype("int")
 
    # draw the prediction on the frame
        label = "{}: {:.2f}%".format(CLASSES[idx],confidence * 100)
        cv2.rectangle(frame, (startX, startY), (endX, endY),COLORS[idx], 2)
        y = startY - 15 if startY - 15 > 15 else startY + 15
        cv2.putText(frame,label, (startX, y),cv2.FONT_HERSHEY_SIMPLEX, 0.5, COLORS[idx], 2)
        #alert.play()
        
# show the output frame
 
 #cv2.putText(frame,count, bottomLeftCornerOfText,cv2.FONT_HERSHEY_SIMPLEX, 0.5, fontColor, 2)
 #cv2.imshow("Frame", raw_frame)
 
 raw_frame1=cv2.resize(raw_frame,(704,576))
 #raw_frame1 = cv2.cvtColor(raw_frame1, cv2.COLOR_BGR2GRAY)
 #print(framess.shape,raw_frame1.shape)
 print('Executed')
 out.write(raw_frame1)
 key = cv2.waitKey(1) & 0xFF
 
# if the `q` key was pressed, break from the loop
 if key == ord("q"):
   break
 
# update the FPS counter
 #fps.update()
# Out:
# [INFO] starting video stream...
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# Executed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-ea2c5c5bc6a4> in <module>()
#      57  # to have a maximum width of 400 pixels
#      58
# ---> 59  ret,frame = vs.read()
#      60  framess=frame
#      61  #frame = imutils.resize(frame, width=800)
#
# KeyboardInterrupt:
