# %%
from PIL import Image
import cv2
import os,sys
path='final_images5/'
dirs=os.listdir(path)
path_new="airtel_images_new/"
def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            try:
             im=Image.open(path+item)
             f,e=os.path.splitext(path_new+item)
             imresize=im.resize((224,224),Image.ANTIALIAS)            
             imresize.save(f+'.jpg','JPEG',quality=90)
            except:
                continue
resize()

# %%
from keras.preprocessing.image import load_img
import numpy as np
from natsort import natsorted
import cv2
from os import listdir
from os.path import isfile,join
my_path='airtel_images_new'
only_files=[f for f in listdir(my_path) if isfile(join(my_path,f))]
#only_files.sort()
only_files=natsorted(only_files)
#only_files.sort(key=lambda f:int(filter(str.isdigit,f)))
print(only_files)
images=np.empty(len(only_files),dtype=object)
for n in range(0,len(only_files)):
 images[n]=cv2.imread(join(my_path,only_files[n]))
 #images[n] = load_img(join(my_path,only_files[n]), target_size=(224, 224))
# Out:
# ['000000.jpg', '000001.jpg', '000002.jpg', '000003.jpg', '000004.jpg', '000005.jpg', '000006.jpg', '000007.jpg', '000008.jpg', '000009.jpg', '0010.jpg', '0011.jpg', '0012.jpg', '0013.jpg', '0014.jpg', '0015.jpg', '0016.jpg', '0017.jpg', '0018.jpg', '0019.jpg', '0020.jpg', '0021.jpg', '0022.jpg', '0023.jpg', '0024.jpg', '0025.jpg', '0026.jpg', '0027.jpg', '0028.jpg', '0029.jpg', '0030.jpg', '0031.jpg', '0032.jpg', '0033.jpg', '0034.jpg', '0035.jpg', '0036.jpg', '0037.jpg', '0038.jpg', '0039.jpg', '0040.jpg', '0041.jpg', '0042.jpg', '0043.jpg', '0044.jpg', '0045.jpg', '0046.jpg', '0047.jpg', '0048.jpg', '0049.jpg', '0050.jpg', '0051.jpg', '0052.jpg', '0053.jpg', '0054.jpg', '0055.jpg', '0056.jpg', '0057.jpg', '0058.jpg', '0059.jpg', '0060.jpg', '0061.jpg', '0062.jpg', '0063.jpg', '0064.jpg', '0065.jpg', '0066.jpg', '0067.jpg', '0068.jpg', '0069.jpg', '0070.jpg', '0071.jpg', '0072.jpg', '0073.jpg', '0074.jpg', '0075.jpg', '0076.jpg', '0077.jpg', '0078.jpg', '0079.jpg', '0080.jpg', '0081
# ...

# %%
import pandas as pd
#target2 = pd.read_csv('airtel.csv')
#target1 = pd.read_csv('dataset_airtelstore.csv')

# %%
target = pd.read_csv('airtel_data_extended.csv')

# %%
tar1=target1['No of people']
tar2=target2['No. of Persons']

# %%
print(target.head(n=5))
# Out:
#   sno  persons
# 0   0      6.0
# 1   1      7.0
# 2   2      6.0
# 3   3      8.0
# 4   4      8.0

# %%
print(target.head(n=5))
# Out:
#    0    6
# 0  1  7.0
# 1  2  6.0
# 2  3  8.0
# 3  4  8.0
# 4  5  8.0

# %%
print(target1.shape)
print(target2.shape)
print(target.shape)
# Out:
# (148, 2)
# (329, 2)
# (477, 2)

# %%
target=pd.concat([tar1, tar2])

# %%
tempa=target['persons']

# %%
print(target.shape)
# Out:
# (5147, 2)

# %%
print(tempa[0])
# Out:
# 6.0

# %%
print(images.shape)
# Out:
# (5147,)

# %%
data_size=5147

def create_sequences():
 dataset=np.ndarray(shape=(5147,224,224,3),dtype=np.float32) 
 data_labels=[]
 i=0
 w=0
 while i<data_size:
        #print images_1[i].shape
        temp=np.hstack([images[i]])
        dataset[i,:,:]=temp
        temp_str=str(tempa[i])
        data_labels.append(tempa[i])
        
        w+=1
        i+=1
        np.array(data_labels)
 return dataset,data_labels
dataset,data_labels=create_sequences()

# %%
print (dataset.shape)
print (len(data_labels))
# Out:
# (2920, 224, 224, 3)
# 2920

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range (0,10):
    fig=plt.figure()
    print(tempa[i])
    plt.imshow(images[i])
    #print(i)
    plt.show()
    #print(Y[i])
# Out:
# 6
# 7
# 6
# 8
# 8
# 8
# 6
# 6
# 6
# 6

# %%
import pandas as pd
data_labels=pd.DataFrame(data_labels)
#data_labels=data_labels.T

# %%
import pandas as pd
tempa=pd.DataFrame(tempa)
tempa.to_csv('tempa.csv')

# %%
tempa=pd.read_csv('tempa.csv')

# %%
target=tempa['0']

# %%
#y_train_raw = np.array(data_labels, np.uint8)
#x_train_raw = np.array(dataset,np.float32)/ 255
from sklearn.cross_validation import train_test_split
X_train,X_test,y_train,y_test=train_test_split(dataset,data_labels,test_size=0.2,random_state=369)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet50 import ResNet50
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.mobilenet import MobileNet
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense,Flatten
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K
from keras.applications.mobilenet import MobileNet
# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)
#base_model = MobileNet(input_shape=None, alpha=1.0, depth_multiplier=1, dropout=1e-3, include_top=False, weights='imagenet', input_tensor=None, pooling=None, classes=1000)
#base_model = InceptionResNetV2(weights='imagenet', include_top=False)
#base_model = ResNet50(weights='imagenet', include_top=False)
#base_model =MobileNet(weights = "imagenet",include_top=False,input_shape = (224, 224, 3))
#base_model = VGG16(weights='imagenet', include_top=False)
# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
print(x.shape)
#x=Flatten()(x)
#x = Dense(5024, activation='relu')(x)
#x = Dense(2824, activation='relu')(x)
#x = Dense(1524, activation='relu')(x)
x = Dense(1124, activation='relu')(x)
x = Dense(234, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(1)(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# (?, 2048)

# %%
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='adam', loss='mean_squared_error',metrics=['mse','acc'])

# %%
model.fit(dataset,data_labels,epochs=20, batch_size=8,validation_split=0.05,shuffle=True)
#model.fit(dataset,data_labels,epochs=10, batch_size=16)
# Out:
# Train on 4632 samples, validate on 515 samples
# Epoch 1/20
# 4632/4632 [==============================] - 396s 85ms/step - loss: 10.0914 - mean_squared_error: 10.0914 - acc: 0.1744 - val_loss: 1.9030 - val_mean_squared_error: 1.9030 - val_acc: 0.2350
# Epoch 2/20
# 4632/4632 [==============================] - 394s 85ms/step - loss: 6.9915 - mean_squared_error: 6.9915 - acc: 0.2254 - val_loss: 1.9484 - val_mean_squared_error: 1.9484 - val_acc: 0.2039
# Epoch 3/20
# 4632/4632 [==============================] - 393s 85ms/step - loss: 5.6942 - mean_squared_error: 5.6942 - acc: 0.2494 - val_loss: 3.2805 - val_mean_squared_error: 3.2805 - val_acc: 0.1029
# Epoch 4/20
# 4632/4632 [==============================] - 392s 85ms/step - loss: 4.9725 - mean_squared_error: 4.9725 - acc: 0.2517 - val_loss: 1.0025 - val_mean_squared_error: 1.0025 - val_acc: 0.3437
# Epoch 5/20
# ...

# %%
model.fit(dataset,data_labels,epochs=30, batch_size=16)

# %%
from keras.models import model_from_json
model_json=model.to_json()
with open('model_crowd_inception.json_8_1','w') as json_file:
    json_file.write(model_json)
model.save_weights("model_crowd_inception_8_1.h5")

print("saved model to Disc")

# %%
json_file=open('model_crowd_inception.json','r')
loaded_model_json=json_file.read()
json_file.close()
loaded_model=model_from_json(loaded_model_json)
loaded_model.load_weights("model_crowd_inception.h5")
print('loaded model from json')
# Out:
# loaded model from json

# %%
from keras.preprocessing.image import load_img

# %%
from PIL import Image
im=Image.open('1814.jpg')
imresize=im.resize((294,294),Image.ANTIALIAS)
imresize.save('my_image.jpg','JPEG',quality=90)
image=cv2.imread('my_image.jpg')
images=np.ndarray(shape=(1,294,294,3),dtype=np.float32) 
temp=np.hstack([image])
images[0,:,:]=temp
#image=np.ndarray(shape=(1,64,64,3),dtype=np.float32) 
#temp=np.hstack([images])
#image[0,:,:]=temp

y1 = model.predict(images)
print(y1)
# Out:
# [[ 3.23035955]]
