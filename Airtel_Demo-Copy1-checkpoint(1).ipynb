# %%
from keras.models import model_from_json
json_file=open('my_model_11_1_1.json','r')
loaded_model_json=json_file.read()
json_file.close()
loaded_model=model_from_json(loaded_model_json)
loaded_model.load_weights("my_model_11_1_1.h5")
print('loaded model from json')
# Out:
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# loaded model from json

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import pandas as pd
import pymysql
import datetime
dbServerName    = "35.154.4.16"

dbUser          = "demo_ai"
dbPassword      = "xvidia@ai"
dbName          = "demo_ai"

cusrorType      = pymysql.cursors.DictCursor
connectionObject   = pymysql.connect(host=dbServerName, user=dbUser, password=dbPassword,db=dbName,cursorclass=cusrorType)
cursorObject        = connectionObject.cursor()

# %%
#sqlQuery="create table "

#sqlQuery='CREATE TABLE Airtel_sahara (ID INT NOT NULL AUTO_INCREMENT,camera_name VARCHAR(30),camera_rtsp VARCHAR(100),date DATE, time TIME,count INT,PRIMARY KEY(ID));' 

#cursorObject.execute(sqlQuery)
#data=cursorObject.fetchall()
#print(data)
# Out:
# 0

# %%
sqlQuery='select * from Airtel_sahara' 

cursorObject.execute(sqlQuery)
data=cursorObject.fetchall()
print(data)
# Out:
# ()

# %%
import datetime


now=datetime.datetime.now()
#datetime.datetime.strptime(str(now), "%Y-%M-%j %H:%M:%S").time()
date=str(now).split()
time=str(date[1]).split(':')
print(time[1])
# Out:
# 43

# %%
import numpy as np
import argparse
import cv2
#from imutils.video import VideoStream
#from imutils.video import FPS
import numpy as np
import argparse
#import imutils
import time
import cv2
#from PIL import Image
sec=0
import datetime


now=datetime.datetime.now()
print(now)

video='rtsp://admin:Admin123@airtelxvidia.selfip.com:8554/h264/ch01/sub/av_stream'
vs=cv2.VideoCapture(str(video))
#fourcc = cv2.VideoWriter_fourcc('M','J','P','G')
#out = cv2.VideoWriter('intrusion_program.avi',fourcc, 20.0, (704,576))
count="Initializing......"
counter=0
while True:
 # grab the frame from the threaded video stream and resize it
 # to have a maximum width of 400 pixels

 ret,frame = vs.read()
 #frame = imutils.rotate(frame, -90)i
 #frame = imutils.resize(frame, width=800)
 #im=Image.open('1814.jpg')
 imresize=cv2.resize(frame, (64, 64)) 
 images=np.ndarray(shape=(1,64,64,3),dtype=np.float32) 
 temp=np.hstack([imresize])
 images[0,:,:]=temp
 mi=now.minute()
 #counter=0
 if mi==0 or mi==15 or mi==30 or mi==45 :
    #counter.append(int(y1[0][0]))
    y1 = loaded_model.predict(images)
    #imresize=cv2.resize(frame, (64, 64)) 
    #imresize=cv2.resize(frame, (294, 294)) 
    #images=np.ndarray(shape=(1,294,294,3),dtype=np.float32) 
    #temp=np.hstack([imresize])
    #images[0,:,:]=temp
    #y1 = loaded_model.predict(images)
    #count = "No of Persons={}".format(int(y1[0][0]))
    #counter1=max(counter)
    #counter=int(counter/31)
    count = "No of Persons={}".format(int(y1[0][0])) 
    
    #counter=[0]
    cursorObject.execute("INSERT INTO Airtel_sahara(camera_name,camera_rtsp,date,time,count) VALUES ('Airtel_sahara','"+str(video)+"','"+str(date)+"','"+str(time)+str"')")
    connectionObject.commit()   
 #print(y1)
 #print(sec)
 #count = "No of Persons={}".format(int(y1[0][0]))
 #count = "No of Persons={}".format(int(y1[0][0]))
 #cv2.putText(frame,count,(10,50),cv2.FONT_HERSHEY_PLAIN, 1, (125,255,255), 2)
 #cv2.imshow("Frame", frame)
 #print(frame.shape)
 print(count)
 #out.write(frame)
 #key = cv2.waitKey(1) & 0xFF
 
# if the `q` key was pressed, break from the loop
 #if key == ord("q"):
   #break
# Out:
# 2018-01-19 09:21:19.490532
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# Initializing......
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# No of Persons=6
# ...
